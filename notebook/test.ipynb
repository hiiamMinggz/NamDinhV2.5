# %%
import pandas as pd
from underthesea import word_tokenize
import re
from itertools import chain

# %%
df = pd.read_csv('../data/new_procedure.csv',escapechar='\\', skipinitialspace=True)
df.head()
# Out:
#                                                   id  \
# 0  thủ tục chuyển nhượng toàn bộ hoặc một phần dự...
# 1  thủ tục cấp mới chứng chỉ hành nghề môi giới b...
# 2  thủ tục cấp lại (cấp đổi) chứng chỉ hành nghề ...
# 3  thủ tục thông báo nhà ở hình thành trong tương...
# 4  thủ tục cho thuê, thuê mua nhà ở xã hội thuộc ...
#
#                                       procedure_name  \
# 0  thu tuc chuyen nhuong toan bo hoac mot phan du...
# 1  thu tuc cap moi chung chi hanh nghe moi gioi b...
# 2  thu tuc cap lai (cap doi) chung chi hanh nghe ...
# 3  thu tuc thong bao nha o hinh thanh trong tuong...
# 4  thu tuc cho thue, thue mua nha o xa hoi thuoc ...
#
#                                            LinhVuc  \
# 0  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 1  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 2  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 3  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 4  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
#
# ...

# %%
def loaddicchar():
    dic = {}
    char1252 = 'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ'.split(
        '|')
    charutf8 = "à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ".split(
        '|')
    for i in range(len(char1252)):
        dic[char1252[i]] = charutf8[i]
    return dic


dicchar = loaddicchar()


def covert_unicode(txt):
    return re.sub(
        r'à|á|ả|ã|ạ|ầ|ấ|ẩ|ẫ|ậ|ằ|ắ|ẳ|ẵ|ặ|è|é|ẻ|ẽ|ẹ|ề|ế|ể|ễ|ệ|ì|í|ỉ|ĩ|ị|ò|ó|ỏ|õ|ọ|ồ|ố|ổ|ỗ|ộ|ờ|ớ|ở|ỡ|ợ|ù|ú|ủ|ũ|ụ|ừ|ứ|ử|ữ|ự|ỳ|ý|ỷ|ỹ|ỵ|À|Á|Ả|Ã|Ạ|Ầ|Ấ|Ẩ|Ẫ|Ậ|Ằ|Ắ|Ẳ|Ẵ|Ặ|È|É|Ẻ|Ẽ|Ẹ|Ề|Ế|Ể|Ễ|Ệ|Ì|Í|Ỉ|Ĩ|Ị|Ò|Ó|Ỏ|Õ|Ọ|Ồ|Ố|Ổ|Ỗ|Ộ|Ờ|Ớ|Ở|Ỡ|Ợ|Ù|Ú|Ủ|Ũ|Ụ|Ừ|Ứ|Ử|Ữ|Ự|Ỳ|Ý|Ỷ|Ỹ|Ỵ',
        lambda x: dicchar[x.group()], txt)

# %%
def remove_tone_line(utf8_str):
    intab_l = "ạảãàáâậầấẩẫăắằặẳẵóòọõỏôộổỗồốơờớợởỡéèẻẹẽêếềệểễúùụủũưựữửừứíìịỉĩýỳỷỵỹđ"
    intab_u = "ẠẢÃÀÁÂẬẦẤẨẪĂẮẰẶẲẴÓÒỌÕỎÔỘỔỖỒỐƠỜỚỢỞỠÉÈẺẸẼÊẾỀỆỂỄÚÙỤỦŨƯỰỮỬỪỨÍÌỊỈĨÝỲỶỴỸĐ"
    intab = list(intab_l+intab_u)

    outtab_l = "a"*17 + "o"*17 + "e"*11 + "u"*11 + "i"*5 + "y"*5 + "d"
    outtab_u = "A"*17 + "O"*17 + "E"*11 + "U"*11 + "I"*5 + "Y"*5 + "D"
    outtab = outtab_l + outtab_u

    r = re.compile("|".join(intab))
    replaces_dict = dict(zip(intab, outtab))
    return r.sub(lambda m: replaces_dict[m.group(0)], utf8_str)

# %%
df['id'] = df['id'].apply(covert_unicode)

# %%
df['procedure_name'] = df['id'].apply(remove_tone_line)

# %%
df.head()
# Out:
#                                                   id  \
# 0  thủ tục chuyển nhượng toàn bộ hoặc một phần dự...
# 1  thủ tục cấp mới chứng chỉ hành nghề môi giới b...
# 2  thủ tục cấp lại (cấp đổi) chứng chỉ hành nghề ...
# 3  thủ tục thông báo nhà ở hình thành trong tương...
# 4  thủ tục cho thuê, thuê mua nhà ở xã hội thuộc ...
#
#                                       procedure_name  \
# 0  thu tuc chuyen nhuong toan bo hoac mot phan du...
# 1  thu tuc cap moi chung chi hanh nghe moi gioi b...
# 2  thu tuc cap lai (cap doi) chung chi hanh nghe ...
# 3  thu tuc thong bao nha o hinh thanh trong tuong...
# 4  thu tuc cho thue, thue mua nha o xa hoi thuoc ...
#
#                                            LinhVuc  \
# 0  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 1  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 2  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 3  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 4  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
#
# ...

# %%
df.to_csv('../data/ND_procedure.csv', index=False)

# %%
df['id'] = df.loc[:, 'procedure_name']

# %%
df.info
# Out:
# <bound method DataFrame.info of                                          procedure_name  \
# 0     thủ tục chuyển nhượng toàn bộ hoặc một phần dự...
# 1     thủ tục cấp mới chứng chỉ hành nghề môi giới b...
# 2     thủ tục cấp lại (cấp đổi) chứng chỉ hành nghề ...
# 3     thủ tục thông báo nhà ở hình thành trong tương...
# 4     thủ tục cho thuê, thuê mua nhà ở xã hội thuộc ...
# ...                                                 ...
# 1791  thủ tục thuyên chuyển đối tượng học bổ túc tru...
# 1792    thủ tục chuyển trường đối với học sinh tiểu học
# 1793  thủ tục đặt và tặng giải thưởng về khoa học và...
# 1794         thủ tục hỗ trợ ăn trưa cho trẻ em mẫu giáo
# 1795  thủ tục đăng ký thông tin kết quả nghiên cứu k...
#
#                                               LinhVuc  \
# 0     Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 1     Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 2     Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# ...

# %%
df.head()
# Out:
#                                       procedure_name  \
# 0  thủ tục chuyển nhượng toàn bộ hoặc một phần dự...
# 1  thủ tục cấp mới chứng chỉ hành nghề môi giới b...
# 2  thủ tục cấp lại (cấp đổi) chứng chỉ hành nghề ...
# 3  thủ tục thông báo nhà ở hình thành trong tương...
# 4  thủ tục cho thuê, thuê mua nhà ở xã hội thuộc ...
#
#                                            LinhVuc  \
# 0  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 1  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 2  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 3  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 4  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
#
#                                       Coquanthuchien  \
# 0  - Cơ quan có thẩm quyền quyết định: UBND cấp t...
# 1                                       Sở Xây dựng.
# 2                                        Sở Xây dựng
# 3  Cơ quan thực hiện: Sở Xây dựng\nĐịa chỉ tiếp n...
# 4  - Cơ quan có thẩm quyền quyết định: UBND cấp t...
#
# ...

# %%
df['procedure_name'] = df['procedure_name'].apply(remove_tone_line)

# %%
df.head()
# Out:
#                                       procedure_name  \
# 0  thu tuc chuyen nhuong toan bo hoac mot phan du...
# 1  thu tuc cap moi chung chi hanh nghe moi gioi b...
# 2  thu tuc cap lai (cap doi) chung chi hanh nghe ...
# 3  thu tuc thong bao nha o hinh thanh trong tuong...
# 4  thu tuc cho thue, thue mua nha o xa hoi thuoc ...
#
#                                            LinhVuc  \
# 0  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 1  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 2  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 3  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 4  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
#
#                                       Coquanthuchien  \
# 0  - Cơ quan có thẩm quyền quyết định: UBND cấp t...
# 1                                       Sở Xây dựng.
# 2                                        Sở Xây dựng
# 3  Cơ quan thực hiện: Sở Xây dựng\nĐịa chỉ tiếp n...
# 4  - Cơ quan có thẩm quyền quyết định: UBND cấp t...
#
# ...

# %%
df.to_csv('../data/new_procedure.csv', index=False)

# %%
cols = df.columns.tolist()

# %%
cols = cols[-1:] + cols[:-1]

# %%
cols
# Out:
# ['id',
#  'procedure_name',
#  'LinhVuc',
#  'Coquanthuchien',
#  'Cachthucthuchien',
#  'Doituongthuchien',
#  'Thoigiangiaiquyet',
#  'Lephi',
#  'Mautokhai',
#  'Ketquathuchien',
#  'Trinhtu',
#  'Hoso',
#  'Dieukien',
#  'Phaply',
#  'Taive_array',
#  'Donvi_array']

# %%
df = df[cols]

# %%
df.head()
# Out:
#                                                   id  \
# 0  thủ tục chuyển nhượng toàn bộ hoặc một phần dự...
# 1  thủ tục cấp mới chứng chỉ hành nghề môi giới b...
# 2  thủ tục cấp lại (cấp đổi) chứng chỉ hành nghề ...
# 3  thủ tục thông báo nhà ở hình thành trong tương...
# 4  thủ tục cho thuê, thuê mua nhà ở xã hội thuộc ...
#
#                                       procedure_name  \
# 0  thu tuc chuyen nhuong toan bo hoac mot phan du...
# 1  thu tuc cap moi chung chi hanh nghe moi gioi b...
# 2  thu tuc cap lai (cap doi) chung chi hanh nghe ...
# 3  thu tuc thong bao nha o hinh thanh trong tuong...
# 4  thu tuc cho thue, thue mua nha o xa hoi thuoc ...
#
#                                            LinhVuc  \
# 0  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 1  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 2  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 3  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
# 4  Lĩnh vực Quản lý nhà ở, kinh doanh bất động sản
#
# ...

# %%
df_khaisinh = df[df.id.str.contains(covert_unicode('thuốc phiện'))]
df_khaisinh
# Out:
#                                                     id  \
# 504  công bố đủ điều kiện điều trị nghiện chất dạng...
# 507  công bố lại đối với cơ sở đủ điều kiện điều tr...
#
#                                         procedure_name  \
# 504  cong bo du dieu kien dieu tri nghien chat dang...
# 507  cong bo lai doi voi co so du dieu kien dieu tr...
#
#                     LinhVuc Coquanthuchien  \
# 504  Lĩnh vực Y tế dự phòng        Sở Y tế
# 507  Lĩnh vực Y tế dự phòng        Sở Y tế
#
#                                       Cachthucthuchien  \
# 504  Nộp trực tiếp hoặc gửi hồ sơ công bố (theo địn...
# 507  Nộp trực tiếp hoặc gửi hồ sơ công bố (theo địn...
#
#                                       Doituongthuchien  \
# 504  Cơ sở điều trị nghiện các chất dạng thuốc phiệ...
# 507  Cơ sở điều trị nghiện các chất dạng thuốc phiệ...
#
#                                      Thoigiangiaiquyet               Lephi  \
# ...

# %%
# Out:
# test.ipynb  tmp.txt

# %%
f = open('../json_data/action.json', 'r', encoding='utf-8')
content = f.read()
content = remove_tone_line(content)
content
# Out:
# '{\n    "LinhVuc":["linh vuc", "Linh vuc"],\n    "Coquanthuchien":["co quan thuc hien", "Co quan thuc hien", "co quan nao", "co quan", "Don vi nao", "don vi"],\n    "Cachthucthuchien":["cach thuc thuc hien", "truc tuyen", "truc tiep", "qua duong buu dien", "buu dien"],\n    "Doituongthuchien":["Doi tuong thuc hien"],\n    "Thoigiangiaiquyet":["thoi gian giai quyet","thoi han giai quyet"],\n    "Lephi":["le phi", "Le phi", "chi phi", "bao nhieu tien","mat tien khong","phi"],\n    "Mautokhai":["mau don", "mau to khai", "mau thu tuc"],\n    "Ketquathuchien":["ket qua thuc hien"],\n    "Trinhtu":["trinh tu", "cac buoc","quy trinh","thuc hien"], \n    "Hoso":["ho so", "giay to can nop", "giay to can chuan bi", "can nop giay to", "can chuan bi giay to", "giay to phai xuat trinh", "giay to phai nop", "phai xuat trinh giay to", "phai nop giay to", "phai chuan bi giay to","nhung giay to","nhung ho so"],\n    "Dieukien":["dieu kien", "co duoc"]\n}'

# %%
f = open('ming.json', 'w', encoding='utf-8')
f.write(content)
# Out:
# 938

# %%
def remove_dup(procedure_list:list):
    mylist = list(dict.fromkeys(procedure_list))
    return mylist

# %%
def split_verb_phrase(list_procedure:list):
    result_list = ['có yếu tố nước ngoài', 'cho người đã có hồ sơ, giấy tờ cá nhân','lần đầu','lần hai']
    tmp_list = []
    for procedure in list_procedure:
        procedure = procedure.replace(result_list[0], '').strip()
        procedure = procedure.replace(result_list[1], '').strip()
        tmp_list.append(procedure)
        tmp_list = sorted(remove_dup(tmp_list), key=len, reverse=True)
    result_list = tmp_list + result_list
    return(result_list)

# %%
split_verb_phrase(list_procedure)
# Out:
# ['thủ tục ghi vào sổ hộ tịch việc hộ tịch khác của công dân việt nam đã được giải quyết tại cơ quan có thẩm quyền của nước ngoài (khai sinh; giám hộ; nhận cha, mẹ, con; xác định cha, mẹ, con; nuôi con nuôi; khai tử; thay đổi hộ tịch)',
#  'khai tử lưu động',
#  'lại khai tử',
#  'khai tử',
#  'có yếu tố nước ngoài',
#  'cho người đã có hồ sơ, giấy tờ cá nhân']

# %%
keyword_dictionary = {
    'khai sinh lưu động': ['khai sinh lưu động'],
    'lại khai sinh': ['lại khai sinh'],
    'khai sinh': ['khai sinh'],
    'nhận cha, mẹ, con': ['nhận cha, mẹ, con'],
    'kết hôn lưu động': ['kết hôn lưu động'],
    'lại kết hôn': ['lại kết hôn'],
    'kết hôn': ['kết hôn'],
    'khai tử lưu động': ['khai tử lưu động'],
    'lại khai tử': ['lại khai tử'],
    'khai tử': ['khai tử'],
    'ly hôn': ['ly hôn'],
    'biến động quyền sử dụng đất': ['biến động quyền sử dụng đất'],
    'đăng ký đất đai': ['đăng ký đất đai'],
    'tranh chấp đất đai': ['tranh chấp đất đai'],
    'khám chữa bệnh': ['khám chữa bệnh'],
    'bảo hiểm y tế': ['bảo hiểm y tế'],
    'bảo hiểm xã hội': ['bảo hiểm xã hội'],
    'an toàn lao động': ['an toàn lao động'],
    'trợ cấp thất nghiệp': ['trợ cấp thất nghiệp'],
    'thất nghiệp': ['thất nghiệp'],
    'chứng thực di chúc': ['chứng thực di chúc'],
    'di chúc': ['di chúc'],

    'có yếu tố nước ngoài': ['có yếu tố nước ngoài', 'người nước ngoài', 'nước ngoài'],
    'cho người đã có hồ sơ, giấy tờ cá nhân': ['cho người đã có hồ sơ, giấy tờ cá nhân'],
    'lần đầu': ['lần đầu'],
    'lần hai': ['lần hai'],
    'thanh toán': ['thanh toán'],
    'cấp thẻ': ['cấp thẻ'],
    'một lần': ['một lần'],
    'trợ cấp': ['trợ cấp'],
    'chứng thực': ['chứng thực']

}

# %%
import json

# %%
with open("../json/keyword.json", "w", encoding='utf-8') as outfile:
    json.dump(keyword_dictionary, outfile, indent=4, ensure_ascii=False)

# %%
BOT_MEMORY = {'keywords' : [], 'action':None}

# %%
def bot_understand(user_question:str):
    global BOT_MEMORY
    keyword_list = []
    #load keyword dictionary
    with open('../json/keyword.json','r', encoding='utf-8') as f:
        keyword_dict = json.load(f)
    for key in keyword_dict.keys():
        for val in keyword_dict[key]:
            if val in user_question:
                keyword_list.append(key)
                user_question = user_question.replace(val, '')
    BOT_MEMORY.update({'keywords': keyword_list})
    return BOT_MEMORY

# %%
bot_understand('Các bước đăng ký lại kết hôn với người nước ngoài')
# Out:
# {'keywords': ['lại kết hôn', 'có yếu tố nước ngoài'], 'action': None}

# %%
# tiếp theo thử nghiệm search
# 1. cộng động từ
# 2. duplicate(df[v1] + df[v2])
# lấy top 5

# %%
from itertools import chain
import pandas as pd
import re

# %%
keywords = ['lại kết hôn', 'có yếu tố nước ngoài']

# %%
import pandas as pd
List = ['kết hôn', 'kết hôn', 'kết hôn', 'mingg', 'mingg','mingg','mingg']
 
# Create a panda DataFrame using the list
df=pd.DataFrame({'Number': List})
 
# Creating a new dataframe to store the values
# with appropriate column name
# value_counts() returns the count based on
# the grouped column values
df1 = pd.DataFrame(data=df['Number'].value_counts())
# The values in the List become the index of the new dataframe.
# Setting these index as a column
df1['Count']=df1['Number'].index
 
# Fetch the list of frequently repeated columns
list(df1[df1['Number']>=2]['Count'])
# Out:
# ['mingg', 'kết hôn']

# %%
def search_token_in_database(user_token):
    df = pd.read_csv('../data/new_procedure.csv', engine='python')
    procedures = df[df.procedure_name.str.extract(user_token,  flags=re.IGNORECASE)]
    # flatten 2d list
    procedure_list = list(chain.from_iterable(procedures.values.tolist()))
    procedure_list = sorted(procedure_list, key=len)
    return procedure_list

# %%
user_sent ="kết hôn"

# %%
list_user_token = word_tokenize(user_sent)

# %%
list_user_token
# Out:
# ['kết hôn']

# %%
tmp = []
for token in list_user_token:
    tmp+= search_token_in_database(token)
len(tmp)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_5582/2895859316.py in <module>
#       1 tmp = []
#       2 for token in list_user_token:
# ----> 3     tmp+= search_token_in_database(token)
#       4 len(tmp)
#
# /tmp/ipykernel_5582/4105413141.py in search_token_in_database(user_token)
#       1 def search_token_in_database(user_token):
#       2     df = pd.read_csv('../data/new_procedure.csv', engine='python')
# ----> 3     procedures = df[df.procedure_name.str.extract(user_token,  flags=re.IGNORECASE)]
#       4     # flatten 2d list
#       5     procedure_list = list(chain.from_iterable(procedures.values.tolist()))
#
# ~/.pyenv/versions/3.7.9/lib/python3.7/site-packages/pandas/core/strings/accessor.py in wrapper(self, *args, **kwargs)
#     114                 )
#     115                 raise TypeError(msg)
# ...

# %%
tmp[:5]
# Out:
# ['giải thể tự nguyện hợp tác xã',
#  'giải thể tự nguyện liên hiệp hợp tác xã',
#  'xác nhận nguồn gốc gỗ trước khi xuất khẩu',
#  'thủ tục cấp lại giấy phép tài nguyên nước',
#  'cấp giấy phép mua bán nguyên liệu thuốc lá']

# %%
df = pd.DataFrame({'Number': tmp})
 
# Creating a new dataframe to store the values
# with appropriate column name
# value_counts() returns the count based on
# the grouped column values
df1 = pd.DataFrame(data=df['Number'].value_counts())
 
# The values in the List become the index of the new dataframe.
# Setting these index as a column
df1['Count']=df1['Number'].index
 
# Fetch the list of frequently repeated columns
list(df1[df1['Number']>=df1.Number.max()-3]['Count'])
# Out:
# ['giải quyết chế độ đối với thương binh đang hưởng chế độ mất sức lao động',
#  'giải quyết hưởng thêm một chế độ trợ cấp đối với thương binh đồng thời là bệnh binh']

# %%
string = "điều chỉnh tiền cấp quyen khai thác tài nguyên nước"

# %%
mingg = re.search(r'\bquy\b', string)
